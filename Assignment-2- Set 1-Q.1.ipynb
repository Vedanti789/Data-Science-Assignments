# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=300
# %matplotlib inline

# %%
df = pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

df
# Out:
# 0     24.23
# 1     25.53
# 2     25.41
# 3     24.14
# 4     29.62
# 5     28.25
# 6     25.81
# 7     24.39
# 8     40.26
# 9     32.95
# 10    91.36
# 11    25.99
# 12    39.42
# 13    26.71
# 14    35.00
# dtype: float64

# %%
name = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanle','Sun Microsystems','Travelers','US Airways','Warner-Lambert']
name
# Out:
# ['Allied Signal',
#  'Bankers Trust',
#  'General Mills',
#  'ITT Industries',
#  'J.P.Morgan & Co.',
#  'Lehman Brothers',
#  'Marriott',
#  'MCI',
#  'Merrill Lynch',
#  'Microsoft',
#  'Morgan Stanle',
#  'Sun Microsystems',
#  'Travelers',
#  'US Airways',
#  'Warner-Lambert']

# %%
sns.boxplot(df)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.scatterplot(x=df, y=name, palette='Red',size=25)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df, y=name)

# %%
df.mean()

# %%
df.var()

# %%
df.std()
